# %%
# Read data
import pandas as pd
import numpy as np

crime_data = pd.read_csv('data/2021.csv')

# %%
# Pre-processing and format conversion
crime_data['Month'] = pd.to_datetime(crime_data['Date']).dt.month

crime_data.drop('ID', axis=1, inplace=True)
crime_data.drop('Case Number', axis=1, inplace=True)
crime_data.drop('IUCR', axis=1, inplace=True)
crime_data.drop('Beat', axis=1, inplace=True)
crime_data.drop('Updated On', axis=1, inplace=True)
crime_data.drop('Latitude', axis=1, inplace=True)
crime_data.drop('Longitude', axis=1, inplace=True)
crime_data.drop('Location', axis=1, inplace=True)
crime_data.drop('FBI Code', axis=1, inplace=True)
crime_data.drop('Block', axis=1, inplace=True)
crime_data.drop('X Coordinate', axis=1, inplace=True)
crime_data.drop('Y Coordinate', axis=1, inplace=True)
crime_data.drop('Date', axis=1, inplace=True)
crime_data.drop('Year', axis=1, inplace=True)


display(crime_data.head())

for col in crime_data.columns:
    crime_data[col] = col + '-' + crime_data[col].astype(str)
    
display(crime_data.head())
# Out:
#          Primary Type                                        Description  \
# 0  DECEPTIVE PRACTICE                              ILLEGAL USE CASH CARD
# 1             BATTERY                            DOMESTIC BATTERY SIMPLE
# 2         SEX OFFENSE  NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL...
# 3     CRIMINAL DAMAGE                                         TO VEHICLE
# 4             ASSAULT                                             SIMPLE
#
#              Location Description  Arrest  Domestic  District  Ward  \
# 0  ATM (AUTOMATIC TELLER MACHINE)   False     False        18  27.0
# 1                       APARTMENT   False      True        11  28.0
# 2                       RESIDENCE   False      True        25  37.0
# 3                          STREET   False     False        25  37.0
# 4    COMMERCIAL / BUSINESS OFFICE   False     False         7  17.0
#
#    Community Area  Month
# 0             8.0      1
# 1            26.0      2
# 2            25.0      2
# 3            25.0      2
# 4            67.0      2
#                       Primary Type  \
# 0  Primary Type-DECEPTIVE PRACTICE
# 1             Primary Type-BATTERY
# 2         Primary Type-SEX OFFENSE
# 3     Primary Type-CRIMINAL DAMAGE
# 4             Primary Type-ASSAULT
#
#                                          Description  \
# 0                  Description-ILLEGAL USE CASH CARD
# 1                Description-DOMESTIC BATTERY SIMPLE
# 2  Description-NON-CONSENSUAL DISSEMINATION OF PR...
# 3                             Description-TO VEHICLE
# 4                                 Description-SIMPLE
#
#                                 Location Description        Arrest  \
# 0  Location Description-ATM (AUTOMATIC TELLER MAC...  Arrest-False
# 1                     Location Description-APARTMENT  Arrest-False
# 2                     Location Description-RESIDENCE  Arrest-False
# 3                        Location Description-STREET  Arrest-False
# 4  Location Description-COMMERCIAL / BUSINESS OFFICE  Arrest-False
#
#          Domestic     District       Ward       Community Area    Month
# 0  Domestic-False  District-18  Ward-27.0   Community Area-8.0  Month-1
# 1   Domestic-True  District-11  Ward-28.0  Community Area-26.0  Month-2
# 2   Domestic-True  District-25  Ward-37.0  Community Area-25.0  Month-2
# 3  Domestic-False  District-25  Ward-37.0  Community Area-25.0  Month-2
# 4  Domestic-False   District-7  Ward-17.0  Community Area-67.0  Month-2

# %%
# Converting to tuples as Apriori takes transaction data as input (list of lists)

crime_data_tuples = [tuple(row) for row in crime_data.values.tolist()]
print("Total number of records =", len(crime_data_tuples))
# Out:
# Total number of records = 158084

# %%
min_support = 0.05
min_confidence = 0.9
min_lift = 1

# %%
# Running Apriori

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from datetime import datetime


te = TransactionEncoder()
te_ary = te.fit(crime_data_tuples).transform(crime_data_tuples)
df = pd.DataFrame(te_ary, columns=te.columns_)
df

start=datetime.now()
frq_items = apriori(df, min_support = min_support, use_colnames = True)
print("Time taken to run Apriori:", datetime.now() - start)
# Out:
# Time taken to run Apriori: 0:00:14.882726

# %%
# Formatting, formatting and writing the frequent itemset to csv

rules = association_rules(frq_items, metric ="lift", min_threshold = min_lift)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules['antecedents_length'] = rules['antecedents'].apply(lambda x: len(x))

rules['consequent support'] = rules['consequent support'].round(decimals = 2)
rules['antecedent support'] = rules['antecedent support'].round(decimals = 2)
rules['support'] = rules['support'].round(decimals = 2)
rules['confidence'] = rules['confidence'].round(decimals = 2)
rules['lift'] = rules['lift'].round(decimals = 2)

filtered_rules = rules[(rules['confidence']  >= min_confidence) ]

print("Number of rules generated:", len(filtered_rules))  

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(filtered_rules.head())
    
filtered_rules.to_csv('data/analysis/2021.csv', columns = ['antecedents','consequents','support','confidence','lift'], sep=',', encoding='utf-8', index=False)
# Out:
# Number of rules generated:  85
#                                     antecedents  \
# 59                    (Description-TO PROPERTY)
# 136     (Arrest-False, Description-TO PROPERTY)
# 42                 (Description-$500 AND UNDER)
# 50                      (Description-OVER $500)
# 96   (Description-$500 AND UNDER, Arrest-False)
#
#                         consequents  antecedent support  consequent support  \
# 59   (Primary Type-CRIMINAL DAMAGE)                0.06                0.12
# 136  (Primary Type-CRIMINAL DAMAGE)                0.06                0.12
# 42             (Primary Type-THEFT)                0.08                0.19
# 50             (Primary Type-THEFT)                0.06                0.19
# 96             (Primary Type-THEFT)                0.07                0.19
#
#      support  confidence  lift  leverage  conviction  antecedents_length
# 59      0.06         1.0  8.10  0.053282         inf                   1
# 136     0.06         1.0  8.10  0.050870         inf                   2
# 42      0.08         1.0  5.28  0.061554         inf                   1
# 50      0.06         1.0  5.28  0.047954         inf                   1
# 96      0.07         1.0  5.28  0.060764         inf                   2

# %%
# Efficient apriori

from efficient_apriori import apriori

start=datetime.now()
itemsets, rules = apriori(crime_data_tuples, min_support=min_support, min_confidence=min_confidence)
print("Time taken to run Efficient Apriori:", datetime.now() - start)
print("Number of rules generated:", len(rules))  
display(rules)
# Out:
# Time taken to run Efficient Apriori: 0:00:00.895615
# Number of rules generated:  79
# [{Description-$500 AND UNDER} -> {Arrest-False},
#  {Description-OVER $500} -> {Arrest-False},
#  {Description-SIMPLE} -> {Arrest-False},
#  {Description-TO PROPERTY} -> {Arrest-False},
#  {Description-TO VEHICLE} -> {Arrest-False},
#  {District-4} -> {Arrest-False},
#  {District-8} -> {Arrest-False},
#  {Location Description-APARTMENT} -> {Arrest-False},
#  {Location Description-RESIDENCE} -> {Arrest-False},
#  {Month-8} -> {Arrest-False},
#  {Month-9} -> {Arrest-False},
#  {Primary Type-ASSAULT} -> {Arrest-False},
#  {Primary Type-CRIMINAL DAMAGE} -> {Arrest-False},
#  {Primary Type-DECEPTIVE PRACTICE} -> {Arrest-False},
#  {Primary Type-THEFT} -> {Arrest-False},
#  {Description-$500 AND UNDER} -> {Domestic-False},
#  {Description-$500 AND UNDER} -> {Primary Type-THEFT},
#  {Description-DOMESTIC BATTERY SIMPLE} -> {Domestic-True},
#  {Description-DOMESTIC BATTERY SIMPLE} -> {Primary Type-BATTERY},
#  {Description-OVER $500} -> {Domestic-False},
#  {Description-OVER $500} -> {Primary Type-THEFT},
#  {Description-TO PROPERTY} -> {Primary Type-CRIMINAL DAMAGE},
#  {Description-TO VEHICLE} -> {Primary Type-CRIMINAL DAMAGE},
#  {Primary Type-DECEPTIVE PRACTICE} -> {Domestic-False},
#  {Primary Type-THEFT} -> {Domestic-False},
#  {Description-$500 AND UNDER, Domestic-False} -> {Arrest-False},
#  {Arrest-False, Description-$500 AND UNDER} -> {Domestic-False},
#  {Description-$500 AND UNDER, Primary Type-THEFT} -> {Arrest-False},
#  {Arrest-False, Description-$500 AND UNDER} -> {Primary Type-THEFT},
#  {Description-$500 AND UNDER} -> {Arrest-False, Primary Type-THEFT},
#  {Arrest-False, Description-DOMESTIC BATTERY SIMPLE} -> {Domestic-True},
#  {Arrest-False, Description-DOMESTIC BATTERY SIMPLE} -> {Primary Type-BATTERY},
#  {Description-OVER $500, Domestic-False} -> {Arrest-False},
#  {Arrest-False, Description-OVER $500} -> {Domestic-False},
#  {Description-OVER $500, Primary Type-THEFT} -> {Arrest-False},
#  {Arrest-False, Description-OVER $500} -> {Primary Type-THEFT},
#  {Description-OVER $500} -> {Arrest-False, Primary Type-THEFT},
#  {Description-SIMPLE, Domestic-False} -> {Arrest-False},
#  {Description-SIMPLE, Primary Type-ASSAULT} -> {Arrest-False},
#  {Description-TO PROPERTY, Primary Type-CRIMINAL DAMAGE} -> {Arrest-False},
#  {Arrest-False, Description-TO PROPERTY} -> {Primary Type-CRIMINAL DAMAGE},
#  {Description-TO PROPERTY} -> {Arrest-False, Primary Type-CRIMINAL DAMAGE},
#  {Description-TO VEHICLE, Primary Type-CRIMINAL DAMAGE} -> {Arrest-False},
#  {Arrest-False, Description-TO VEHICLE} -> {Primary Type-CRIMINAL DAMAGE},
#  {Description-TO VEHICLE} -> {Arrest-False, Primary Type-CRIMINAL DAMAGE},
#  {Domestic-False, Location Description-APARTMENT} -> {Arrest-False},
#  {Domestic-False, Location Description-RESIDENCE} -> {Arrest-False},
#  {Domestic-False, Month-8} -> {Arrest-False},
#  {Domestic-False, Month-9} -> {Arrest-False},
#  {Domestic-False, Primary Type-ASSAULT} -> {Arrest-False},
#  {Domestic-False, Primary Type-CRIMINAL DAMAGE} -> {Arrest-False},
#  {Domestic-False, Primary Type-DECEPTIVE PRACTICE} -> {Arrest-False},
#  {Arrest-False, Primary Type-DECEPTIVE PRACTICE} -> {Domestic-False},
#  {Primary Type-DECEPTIVE PRACTICE} -> {Arrest-False, Domestic-False},
#  {Domestic-False, Primary Type-THEFT} -> {Arrest-False},
#  {Arrest-False, Primary Type-THEFT} -> {Domestic-False},
#  {Description-$500 AND UNDER, Primary Type-THEFT} -> {Domestic-False},
#  {Description-$500 AND UNDER, Domestic-False} -> {Primary Type-THEFT},
#  {Description-$500 AND UNDER} -> {Domestic-False, Primary Type-THEFT},
#  {Description-DOMESTIC BATTERY SIMPLE, Primary Type-BATTERY} -> {Domestic-True},
#  {Description-DOMESTIC BATTERY SIMPLE, Domestic-True} -> {Primary Type-BATTERY},
#  {Description-DOMESTIC BATTERY SIMPLE} -> {Domestic-True, Primary Type-BATTERY},
#  {Description-OVER $500, Primary Type-THEFT} -> {Domestic-False},
#  {Description-OVER $500, Domestic-False} -> {Primary Type-THEFT},
#  {Description-OVER $500} -> {Domestic-False, Primary Type-THEFT},
#  {Description-SIMPLE, Primary Type-BATTERY} -> {Domestic-False},
#  {Description-$500 AND UNDER, Domestic-False, Primary Type-THEFT} -> {Arrest-False},
#  {Arrest-False, Description-$500 AND UNDER, Primary Type-THEFT} -> {Domestic-False},
#  {Arrest-False, Description-$500 AND UNDER, Domestic-False} -> {Primary Type-THEFT},
#  {Description-$500 AND UNDER, Domestic-False} -> {Arrest-False, Primary Type-THEFT},
#  {Arrest-False, Description-$500 AND UNDER} -> {Domestic-False, Primary Type-THEFT},
#  {Arrest-False, Description-DOMESTIC BATTERY SIMPLE, Primary Type-BATTERY} -> {Domestic-True},
#  {Arrest-False, Description-DOMESTIC BATTERY SIMPLE, Domestic-True} -> {Primary Type-BATTERY},
#  {Arrest-False, Description-DOMESTIC BATTERY SIMPLE} -> {Domestic-True, Primary Type-BATTERY},
#  {Description-OVER $500, Domestic-False, Primary Type-THEFT} -> {Arrest-False},
#  {Arrest-False, Description-OVER $500, Primary Type-THEFT} -> {Domestic-False},
#  {Arrest-False, Description-OVER $500, Domestic-False} -> {Primary Type-THEFT},
#  {Description-OVER $500, Domestic-False} -> {Arrest-False, Primary Type-THEFT},
#  {Arrest-False, Description-OVER $500} -> {Domestic-False, Primary Type-THEFT}]

# %%
#References
# https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2/data
# Efficient apriori - https://pypi.org/project/efficient-apriori/
# https://www.geeksforgeeks.org/implementing-apriori-algorithm-in-python/
# http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/
